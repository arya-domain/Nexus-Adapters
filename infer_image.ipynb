# %%
import torch
from PIL import Image
from models.pipeline import StableDiffusionAdapterPipeline
from models.adapter import NexusAdapter
import torch
import os
os.environ['CUDA_DEVICE_ORDER'] = 'PCI_BUS_ID'
os.environ['CUDA_VISIBLE_DEVICES'] = '0'

adapter = NexusAdapter.from_pretrained(f"{MAIN_DIR}/checkpoint-{MODEL_ID}/NexusAdapter")
pipe = StableDiffusionAdapterPipeline.from_pretrained(
	"runwayml/stable-diffusion-v1-5", adapter=adapter
).to('cuda')
pipe.enable_xformers_memory_efficient_attention()
pipe.set_progress_bar_config(leave=False)
pipe.set_progress_bar_config(disable=True)

# %%
# # Example Use Case
# img, con_img, prompts = batch['image'], batch['conditioning_image'], batch['text']
# img, con_img = img.cuda(), con_img.cuda()
# generator = torch.manual_seed(42)
# pred_images = pipe(prompts, image=con_img, generator=generator, output_type='np').images
